# %% [markdown]
# # NBA Game Prediction (2) - Parse Data

# %% [markdown]
# ## Introduction
#
# In this script, we are parsing the HTML content that was scraped in the previous step. This script focuses on extracting the relevant information from the HTML content and transforming it into a structured format for further analysis. We use BeautifulSoup to parse the HTML content and pandas to create and manipulate dataframes.

# %% [markdown]
# ## Importing Necessary Libraries
# We import the necessary libraries. os is used for interacting with the operating system, pandas is used for data manipulation, and BeautifulSoup is used for parsing HTML content.

# %%
import os 
import pandas as pd
from bs4 import BeautifulSoup

# %%
print(os.getcwd())
# Out:
# /Users/ruijiezheng/DS Project/NBA Game Prediction

# %% [markdown]
# ## Defining Constants and Variables
# Here, we define some constants and variables. SCORES_DIR is the directory where our scraped box scores are saved, and box_scores is a list of the box score files.

# %%
SCORES_DIR = "data/scores"

# %%
box_scores = os.listdir(SCORES_DIR)

# %%
len(box_scores)
# Out:
# 1566

# %%
box_scores = [os.path.join(SCORES_DIR, f) for f in box_scores if f.endswith(".html")]

# %% [markdown]
# ## Defining the parse_html Function
# This function is used to parse the HTML content of a box score file. It takes in a box score file, reads its content, and creates a BeautifulSoup object for further parsing.

# %%
def parse_html(box_score):
    with open(box_score) as f:
        html = f.read()
        
    soup = BeautifulSoup(html)
    [s.decompose() for s in soup.select("tr.over_header")]
    [s.decompose() for s in soup.select("tr.thead")]
    return soup

# %% [markdown]
# ## Defining the read_line_score Function
# This function extracts the line score table from the HTML content. It takes in a BeautifulSoup object, finds the line score table, and transforms it into a pandas dataframe.

# %%
def read_line_score(soup):
    line_score = pd.read_html(str(soup), attrs={"id": "line_score"})[0]
    cols = list(line_score.columns)
    cols[0] = "team"
    cols[-1] = "total"
    line_score.columns = cols
    
    line_score = line_score[["team", "total"]]
    return line_score

# %% [markdown]
# ## Defining the read_stats Function
# This function extracts a specific stats table (either basic or advanced) for a specific team from the HTML content.

# %%
def read_stats(soup, team, stat):
    df = pd.read_html(str(soup), attrs = {"id": f"box-{team}-game-{stat}"}, index_col=0)[0]
    df = df.apply(pd.to_numeric, errors="coerce")
    return df

# %%
box_score = box_scores[0]
soup = parse_html(box_score)

line_score = read_line_score(soup)
teams = list(line_score["team"])

summaries = []

for team in teams:
    df = pd.read_html(str(soup), attrs = {"id": f"box-{team}-game-basic"}, index_col=0)[0]

# %%
teams
# Out:
# ['UTA', 'NOP']

# %%
df
# Out:
#                                     MP            FG           FGA  \
# Starters
# Lonzo Ball                       42:07             2            12
# Brandon Ingram                   41:24            15            25
# Josh Hart                        36:35             3             8
# Derrick Favors                   36:07            10            12
# Nicolò Melli                     25:55             3             6
# E'Twaun Moore                    28:25             7            11
# Frank Jackson                    25:36             3             5
# Nickeil Alexander-Walker         16:05             5            11
# Jaxson Hayes                     12:46             3             3
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                        265            51            93
#
#                                    FG%            3P           3PA  \
# Starters
# Lonzo Ball                        .167             1             5
# Brandon Ingram                    .600             3             8
# Josh Hart                         .375             2             5
# Derrick Favors                    .833             0             0
# Nicolò Melli                      .500             1             1
# E'Twaun Moore                     .636             2             3
# Frank Jackson                     .600             0             0
# Nickeil Alexander-Walker          .455             2             4
# Jaxson Hayes                     1.000             0             0
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                       .548            11            26
#
#                                    3P%            FT           FTA  \
# Starters
# Lonzo Ball                        .200             0             0
# Brandon Ingram                    .375            16            20
# Josh Hart                         .400             1             2
# Derrick Favors                     NaN             1             2
# Nicolò Melli                     1.000             0             0
# E'Twaun Moore                     .667             0             1
# Frank Jackson                      NaN             4             6
# Nickeil Alexander-Walker          .500             0             0
# Jaxson Hayes                       NaN             3             4
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                       .423            25            35
#
#                                    FT%           ORB           DRB  \
# Starters
# Lonzo Ball                         NaN             0             4
# Brandon Ingram                    .800             1             7
# Josh Hart                         .500             1             6
# Derrick Favors                    .500             4             7
# Nicolò Melli                       NaN             1             3
# E'Twaun Moore                     .000             0             2
# Frank Jackson                     .667             1             2
# Nickeil Alexander-Walker           NaN             1             0
# Jaxson Hayes                      .750             0             5
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                       .714             9            36
#
#                                    TRB           AST           STL  \
# Starters
# Lonzo Ball                           4            13             0
# Brandon Ingram                       8             6             0
# Josh Hart                            7             0             3
# Derrick Favors                      11             3             2
# Nicolò Melli                         4             0             0
# E'Twaun Moore                        2             1             1
# Frank Jackson                        3             1             1
# Nickeil Alexander-Walker             1             3             1
# Jaxson Hayes                         5             2             0
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                         45            29             8
#
#                                    BLK           TOV            PF  \
# Starters
# Lonzo Ball                           2             2             3
# Brandon Ingram                       1             4             3
# Josh Hart                            1             1             6
# Derrick Favors                       3             1             3
# Nicolò Melli                         0             0             2
# E'Twaun Moore                        0             2             3
# Frank Jackson                        0             2             0
# Nickeil Alexander-Walker             1             0             2
# Jaxson Hayes                         1             1             5
# Zylan Cheatham            Did Not Play  Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play  Did Not Play
# Team Totals                          9            13            27
#
#                                    PTS           +/-
# Starters
# Lonzo Ball                           5           +11
# Brandon Ingram                      49            +1
# Josh Hart                            9            +4
# Derrick Favors                      21            +4
# Nicolò Melli                         7           -18
# E'Twaun Moore                       16            +2
# Frank Jackson                       10           +23
# Nickeil Alexander-Walker            12            +2
# Jaxson Hayes                         9            +1
# Zylan Cheatham            Did Not Play  Did Not Play
# Josh Gray                 Did Not Play  Did Not Play
# Jahlil Okafor             Did Not Play  Did Not Play
# J.J. Redick               Did Not Play  Did Not Play
# Team Totals                        138           NaN

# %%
def read_season_info(soup):
    nav = soup.select("#bottom_nav_container")[0]
    hrefs = [a["href"] for a in nav.find_all("a")]
    season = os.path.basename(hrefs[1]).split("_")[0]
    return season

# %% [markdown]
# ## Reading the Box Scores
# Here, we loop over each box score in box_scores, parse the HTML content, read the line score and stats, and compile the data into a single dataframe.
#
# We set up logging to keep track of the progress and any potential issues during the parsing process.

# %%
## with progress bar and log. try this 

import logging
from tqdm.notebook import tqdm

logging.basicConfig(filename='full_game_scraping.log', level=logging.INFO)

base_cols = None
games = []

# Add tqdm to box_scores for progress bar
for box_score in tqdm(box_scores, desc="Processing box scores"):
    soup = parse_html(box_score)
    line_score = read_line_score(soup)
    teams = list(line_score["team"])

    summaries = []

    for team in teams:
        basic = read_stats(soup, team, "basic")
        advanced = read_stats(soup, team, "advanced")

        totals = pd.concat([basic.iloc[-1, :], advanced.iloc[-1,:]])
        totals.index = totals.index.str.lower()

        maxes = pd.concat([basic.iloc[:-1,:].max(), advanced.iloc[:-1,:].max()])
        maxes.index = maxes.index.str.lower() + "_max"

        summary = pd.concat([totals, maxes])

        if base_cols is None:
            base_cols = list(summary.index.drop_duplicates(keep="first"))
            base_cols = [b for b in base_cols if "bpm" not in b]

        summary = summary[base_cols]

        summaries.append(summary)
    summary = pd.concat(summaries, axis=1).T

    game = pd.concat([summary, line_score], axis = 1)

    game["home"] = [0,1]
    game_opp = game.iloc[::-1].reset_index()
    game_opp.columns += "_opp"

    full_game = pd.concat([game, game_opp], axis=1)

    full_game["season"] = read_season_info(soup)

    full_game["date"] = os.path.basename(box_score)[:8]
    full_game["date"] = pd.to_datetime(full_game["date"], format="%Y%m%d")

    full_game["won"] = full_game["total"] > full_game["total_opp"]

    games.append(full_game)

    # Add logging for every 100 games processed
    if len(games) % 100 == 0:
        logging.info(f"Processed {len(games)} out of {len(box_scores)} games.")
# Out:
# Processing box scores:   0%|          | 0/1564 [00:00<?, ?it/s]

# %%
full_game
# Out:
#       mp     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0  240.0  240.0  41.0  85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 1  240.0  240.0  33.0  85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          27.7          27.1         150.0         126.0       MIA
# 1          51.5          36.2         141.0         114.0       BOS
#
#    total_opp  home_opp  season       date    won
# 0        106         1    2020 2020-09-19   True
# 1        117         0    2020 2020-09-19  False
#
# [2 rows x 150 columns]

# %%
# full_game.to_csv('full_game.csv', index=False)

# %%
games_df = pd.concat(games, ignore_index=True)

# %%
games_df
# Out:
#          mp     mp    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     265.0  265.0  46.0  100.0  0.460  15.0  39.0  0.385  25.0  32.0  ...
# 1     265.0  265.0  51.0   93.0  0.548  11.0  26.0  0.423  25.0  35.0  ...
# 2     240.0  240.0  48.0   91.0  0.527  20.0  41.0  0.488  13.0  21.0  ...
# 3     240.0  240.0  34.0   77.0  0.442  12.0  36.0  0.333  25.0  30.0  ...
# 4     240.0  240.0  38.0   83.0  0.458  12.0  28.0  0.429  16.0  20.0  ...
# ...     ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 3123  240.0  240.0  35.0   94.0  0.372   7.0  32.0  0.219  28.0  34.0  ...
# 3124  240.0  240.0  34.0   82.0  0.415   9.0  33.0  0.273  10.0  16.0  ...
# 3125  240.0  240.0  38.0   89.0  0.427  16.0  37.0  0.432  11.0  13.0  ...
# 3126  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 3127  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             20.7          39.9         160.0         125.0       NOP
# 1             25.0          39.5         197.0         132.0       UTA
# 2             50.0          33.5         147.0         141.0       TOR
# 3             25.2          31.2         197.0         115.0       DET
# 4             41.0          32.0         180.0         118.0       DAL
# ...            ...           ...           ...           ...       ...
# 3123          33.3          45.4         192.0         115.0       GSW
# 3124          26.8          33.4         164.0          99.0       DEN
# 3125          41.5          25.7         226.0         117.0       MIA
# 3126          27.7          27.1         150.0         126.0       MIA
# 3127          51.5          36.2         141.0         114.0       BOS
#
#       total_opp  home_opp  season       date    won
# 0           138         1    2020 2020-01-16  False
# 1           132         0    2020 2020-01-16   True
# 2           105         1    2021 2021-03-03   True
# 3           129         0    2021 2021-03-03  False
# 4           115         1    2021 2021-03-10  False
# ...         ...       ...     ...        ...    ...
# 3123        132         0    2019 2019-04-18  False
# 3124        103         1    2019 2019-02-11  False
# 3125         87         0    2019 2019-02-11   True
# 3126        106         1    2020 2020-09-19   True
# 3127        117         0    2020 2020-09-19  False
#
# [3128 rows x 150 columns]

# %%
# check if there is error in the columns number for each row
[g.shape[1] for g in games if g.shape[1] != 150]
# Out:
# []

# %%
games_df.to_csv("nba_games.csv")

# %% [markdown]
# ## Conclusion
# This script successfully parses the HTML content of NBA box scores and transforms it into a structured format. The parsed data is saved to a CSV file for further analysis. This data will be used in the next step of our project, where we'll explore the data and train a machine learning model to predict the outcome of NBA games.
